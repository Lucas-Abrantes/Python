# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
galaxy_data = pd.read_csv('star_classification.csv')
galaxy_data
# Out:
#              obj_ID       alpha      delta         u         g         r  \
# 0      1.237661e+18  135.689107  32.494632  23.87882  22.27530  20.39501
# 1      1.237665e+18  144.826101  31.274185  24.77759  22.83188  22.58444
# 2      1.237661e+18  142.188790  35.582444  25.26307  22.66389  20.60976
# 3      1.237663e+18  338.741038  -0.402828  22.13682  23.77656  21.61162
# 4      1.237680e+18  345.282593  21.183866  19.43718  17.58028  16.49747
# ...             ...         ...        ...       ...       ...       ...
# 99995  1.237679e+18   39.620709  -2.594074  22.16759  22.97586  21.90404
# 99996  1.237679e+18   29.493819  19.798874  22.69118  22.38628  20.45003
# 99997  1.237668e+18  224.587407  15.700707  21.16916  19.26997  18.20428
# 99998  1.237661e+18  212.268621  46.660365  25.35039  21.63757  19.91386
# 99999  1.237661e+18  196.896053  49.464643  22.62171  21.79745  20.60115
#
#               i         z  run_ID  rerun_ID  cam_col  field_ID   spec_obj_ID  \
# 0      19.16573  18.79371    3606       301        2        79  6.543777e+18
# 1      21.16812  21.61427    4518       301        5       119  1.176014e+19
# 2      19.34857  18.94827    3606       301        2       120  5.152200e+18
# 3      20.50454  19.25010    4192       301        3       214  1.030107e+19
# 4      15.97711  15.54461    8102       301        3       137  6.891865e+18
# ...         ...       ...     ...       ...      ...       ...           ...
# 99995  21.30548  20.73569    7778       301        2       581  1.055431e+19
# 99996  19.75759  19.41526    7917       301        1       289  8.586351e+18
# 99997  17.69034  17.35221    5314       301        4       308  3.112008e+18
# 99998  19.07254  18.62482    3650       301        4       131  7.601080e+18
# 99999  20.00959  19.28075    3650       301        4        60  8.343152e+18
#
#         class  redshift  plate    MJD  fiber_ID
# 0      GALAXY  0.634794   5812  56354       171
# 1      GALAXY  0.779136  10445  58158       427
# 2      GALAXY  0.644195   4576  55592       299
# 3      GALAXY  0.932346   9149  58039       775
# 4      GALAXY  0.116123   6121  56187       842
# ...       ...       ...    ...    ...       ...
# 99995  GALAXY  0.000000   9374  57749       438
# 99996  GALAXY  0.404895   7626  56934       866
# 99997  GALAXY  0.143366   2764  54535        74
# 99998  GALAXY  0.455040   6751  56368       470
# 99999  GALAXY  0.542944   7410  57104       851
#
# [100000 rows x 18 columns]

# %%
galaxy_data.rename({
    'u': 'filtro_ultravioleta',
    'g': 'filtro_verde',
    'r': 'filtro_vermelho',
    'i': 'filtro_infravermelho_proximo',
    'z': 'filtro_infravermelho'
}, axis=1, inplace = True)


galaxy_data.head()
# Out:
#          obj_ID       alpha      delta  filtro_ultravioleta  filtro_verde  \
# 0  1.237661e+18  135.689107  32.494632             23.87882      22.27530
# 1  1.237665e+18  144.826101  31.274185             24.77759      22.83188
# 2  1.237661e+18  142.188790  35.582444             25.26307      22.66389
# 3  1.237663e+18  338.741038  -0.402828             22.13682      23.77656
# 4  1.237680e+18  345.282593  21.183866             19.43718      17.58028
#
#    filtro_vermelho  filtro_infravermelho_proximo  filtro_infravermelho  \
# 0         20.39501                      19.16573              18.79371
# 1         22.58444                      21.16812              21.61427
# 2         20.60976                      19.34857              18.94827
# 3         21.61162                      20.50454              19.25010
# 4         16.49747                      15.97711              15.54461
#
#    run_ID  rerun_ID  cam_col  field_ID   spec_obj_ID   class  redshift  plate  \
# 0    3606       301        2        79  6.543777e+18  GALAXY  0.634794   5812
# 1    4518       301        5       119  1.176014e+19  GALAXY  0.779136  10445
# 2    3606       301        2       120  5.152200e+18  GALAXY  0.644195   4576
# 3    4192       301        3       214  1.030107e+19  GALAXY  0.932346   9149
# 4    8102       301        3       137  6.891865e+18  GALAXY  0.116123   6121
#
#      MJD  fiber_ID
# 0  56354       171
# 1  58158       427
# 2  55592       299
# 3  58039       775
# 4  56187       842

# %%
galaxy_data2 = galaxy_data

galaxy_data2.head()
# Out:
#          obj_ID       alpha      delta  filtro_ultravioleta  filtro_verde  \
# 0  1.237661e+18  135.689107  32.494632             23.87882      22.27530
# 1  1.237665e+18  144.826101  31.274185             24.77759      22.83188
# 2  1.237661e+18  142.188790  35.582444             25.26307      22.66389
# 3  1.237663e+18  338.741038  -0.402828             22.13682      23.77656
# 4  1.237680e+18  345.282593  21.183866             19.43718      17.58028
#
#    filtro_vermelho  filtro_infravermelho_proximo  filtro_infravermelho  \
# 0         20.39501                      19.16573              18.79371
# 1         22.58444                      21.16812              21.61427
# 2         20.60976                      19.34857              18.94827
# 3         21.61162                      20.50454              19.25010
# 4         16.49747                      15.97711              15.54461
#
#    run_ID  rerun_ID  cam_col  field_ID   spec_obj_ID   class  redshift  plate  \
# 0    3606       301        2        79  6.543777e+18  GALAXY  0.634794   5812
# 1    4518       301        5       119  1.176014e+19  GALAXY  0.779136  10445
# 2    3606       301        2       120  5.152200e+18  GALAXY  0.644195   4576
# 3    4192       301        3       214  1.030107e+19  GALAXY  0.932346   9149
# 4    8102       301        3       137  6.891865e+18  GALAXY  0.116123   6121
#
#      MJD  fiber_ID
# 0  56354       171
# 1  58158       427
# 2  55592       299
# 3  58039       775
# 4  56187       842

# %%
galaxy_data2 = galaxy_data[['alpha', 'delta', 'filtro_ultravioleta', 'filtro_verde',
       'filtro_vermelho', 'filtro_infravermelho_proximo',
       'filtro_infravermelho', 'class', 'redshift']]

galaxy_data2.head(15)
# Out:
#          alpha      delta  filtro_ultravioleta  filtro_verde  filtro_vermelho  \
# 0   135.689107  32.494632             23.87882      22.27530         20.39501
# 1   144.826101  31.274185             24.77759      22.83188         22.58444
# 2   142.188790  35.582444             25.26307      22.66389         20.60976
# 3   338.741038  -0.402828             22.13682      23.77656         21.61162
# 4   345.282593  21.183866             19.43718      17.58028         16.49747
# 5   340.995121  20.589476             23.48827      23.33776         21.32195
# 6    23.234926  11.418188             21.46973      21.17624         20.92829
# 7     5.433176  12.065186             22.24979      22.02172         20.34126
# 8   200.290475  47.199402             24.40286      22.35669         20.61032
# 9    39.149691  28.102842             21.74669      20.03493         19.17553
# 10  328.092076  18.220310             25.77163      22.52042         20.63884
# 11  243.986637  25.738280             23.76761      23.79969         20.98318
# 12  345.801874  32.672868             23.17274      20.14496         19.41948
# 13  331.502030  10.035802             20.82940      18.75091         17.51118
# 14  344.984770  -0.352616             23.20911      22.79291         22.08589
#
#     filtro_infravermelho_proximo  filtro_infravermelho   class  redshift
# 0                       19.16573              18.79371  GALAXY  0.634794
# 1                       21.16812              21.61427  GALAXY  0.779136
# 2                       19.34857              18.94827  GALAXY  0.644195
# 3                       20.50454              19.25010  GALAXY  0.932346
# 4                       15.97711              15.54461  GALAXY  0.116123
# 5                       20.25615              19.54544     QSO  1.424659
# 6                       20.60826              20.42573     QSO  0.586455
# 7                       19.48794              18.84999  GALAXY  0.477009
# 8                       19.46490              18.95852  GALAXY  0.660012
# 9                       18.81823              18.65422    STAR -0.000008
# 10                      19.78071              19.05765  GALAXY  0.459596
# 11                      19.80745              19.45579  GALAXY  0.591409
# 12                      19.22034              18.89359    STAR  0.000072
# 13                      17.01631              16.62772  GALAXY  0.152194
# 14                      21.86282              21.85120  GALAXY  0.818160

# %%
fig = plt.figure(figsize =(5, 5))
bplots = plt.boxplot([galaxy_data2["alpha"], galaxy_data2["delta"]],  vert = 1, patch_artist = False)

# %%
fig = plt.figure(figsize =(5, 5))
bplots = plt.boxplot([galaxy_data2["filtro_ultravioleta"], galaxy_data2["filtro_verde"]],  vert = 1, patch_artist = False)

# %%
bplots = plt.boxplot([galaxy_data2["filtro_vermelho"], galaxy_data2["filtro_infravermelho_proximo"]],  vert = 1, patch_artist = False)

# %%
bplots = plt.boxplot([galaxy_data2["filtro_infravermelho"], galaxy_data2["redshift"]],  vert = 1, patch_artist = False)

# %%
galaxy_data2.columns
# Out:
# Index(['alpha', 'delta', 'filtro_ultravioleta', 'filtro_verde',
#        'filtro_vermelho', 'filtro_infravermelho_proximo',
#        'filtro_infravermelho', 'class', 'redshift', 'anomaly_score',
#        'anomaly'],
#       dtype='object')

# %%
from sklearn.ensemble import IsolationForest

# %%
entradas = ['alpha', 'delta', 'filtro_ultravioleta', 'filtro_verde',
            'filtro_vermelho', 'filtro_infravermelho_proximo',
            'filtro_infravermelho', 'redshift']

modelo_IF = IsolationForest(contamination=0.1, random_state=42)

modelo_IF.fit(galaxy_data2[entradas])

galaxy_data2["anomaly_score"] = modelo_IF.decision_function(galaxy_data2[entradas]);
# Out:
# c:\Users\lucas\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# C:\Users\lucas\AppData\Local\Temp\ipykernel_13756\2727980993.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   galaxy_data2["anomaly_score"] = modelo_IF.decision_function(galaxy_data2[entradas]);

# %%
galaxy_data2["anomaly"] = modelo_IF.predict(galaxy_data2[entradas]);
# Out:
# C:\Users\lucas\AppData\Local\Temp\ipykernel_13756\1323683531.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   galaxy_data2["anomaly"] = modelo_IF.predict(galaxy_data2[entradas]);

# %%
# galaxy_data2 = galaxy_data2.drop(["anomalia", "pontuacao_anomalia"], axis=1)

# %%
galaxy_data2
# Out:
#             alpha      delta  filtro_ultravioleta  filtro_verde  \
# 0      135.689107  32.494632             23.87882      22.27530
# 1      144.826101  31.274185             24.77759      22.83188
# 2      142.188790  35.582444             25.26307      22.66389
# 3      338.741038  -0.402828             22.13682      23.77656
# 4      345.282593  21.183866             19.43718      17.58028
# ...           ...        ...                  ...           ...
# 99995   39.620709  -2.594074             22.16759      22.97586
# 99996   29.493819  19.798874             22.69118      22.38628
# 99997  224.587407  15.700707             21.16916      19.26997
# 99998  212.268621  46.660365             25.35039      21.63757
# 99999  196.896053  49.464643             22.62171      21.79745
#
#        filtro_vermelho  filtro_infravermelho_proximo  filtro_infravermelho  \
# 0             20.39501                      19.16573              18.79371
# 1             22.58444                      21.16812              21.61427
# 2             20.60976                      19.34857              18.94827
# 3             21.61162                      20.50454              19.25010
# 4             16.49747                      15.97711              15.54461
# ...                ...                           ...                   ...
# 99995         21.90404                      21.30548              20.73569
# 99996         20.45003                      19.75759              19.41526
# 99997         18.20428                      17.69034              17.35221
# 99998         19.91386                      19.07254              18.62482
# 99999         20.60115                      20.00959              19.28075
#
#         class  redshift  anomaly_score  anomaly
# 0      GALAXY  0.634794       0.080435        1
# 1      GALAXY  0.779136      -0.038229       -1
# 2      GALAXY  0.644195       0.092186        1
# 3      GALAXY  0.932346       0.066902        1
# 4      GALAXY  0.116123      -0.002663       -1
# ...       ...       ...            ...      ...
# 99995  GALAXY  0.000000       0.044168        1
# 99996  GALAXY  0.404895       0.107843        1
# 99997  GALAXY  0.143366       0.034208        1
# 99998  GALAXY  0.455040       0.084963        1
# 99999  GALAXY  0.542944       0.090381        1
#
# [100000 rows x 11 columns]

# %%
galaxy_data2.loc[:, ["filtro_vermelho","filtro_infravermelho_proximo", "anomaly", "anomaly_score"]]

# quanto menor a pontuação, mais anômala é a amostra
# Out:
#        filtro_vermelho  filtro_infravermelho_proximo  anomaly  anomaly_score
# 0             20.39501                      19.16573        1       0.103542
# 1             22.58444                      21.16812        1       0.022713
# 2             20.60976                      19.34857        1       0.096225
# 3             21.61162                      20.50454        1       0.045206
# 4             16.49747                      15.97711        1       0.011349
# ...                ...                           ...      ...            ...
# 99995         21.90404                      21.30548        1       0.027715
# 99996         20.45003                      19.75759        1       0.092397
# 99997         18.20428                      17.69034        1       0.090490
# 99998         19.91386                      19.07254        1       0.087207
# 99999         20.60115                      20.00959        1       0.116318
#
# [100000 rows x 4 columns]

# %%
def graficoOutlier(data, nome_metodo, x1, x2, limite_x = [0, 1], limite_y = [0, 1]):

    print(f"Método outlier: {nome_metodo}")


    print(f"Quantidade de valores anômalos: {len(data[data['anomaly'] == -1])}")
    print(f"Quantidade de valores não anômalos: {len(data[data['anomaly'] == 1])}")
    print(f"Quantidade de valores lidos: {len(data)}")


    grafico = sns.FacetGrid(data, col='anomaly', height=4, hue='anomaly', hue_order=[1, -1])
    grafico.map(sns.scatterplot, x1, x2)

    grafico.fig.suptitle(f"Método outlier: {nome_metodo}", y=1.10, fontweight='bold')
    grafico.set(xlim=limite_x, ylim = limite_y)
    axes = grafico.axes.flatten()
    axes[0].set_title(f"Ouliers\n{len(data[data['anomaly'] == -1])} pontos")
    axes[1].set_title(f"Ouliers\n{len(data[data['anomaly'] == 1])} pontos")

    return grafico

# %%
graficoOutlier(galaxy_data2, 'Isolation Forest', 'filtro_vermelho', 'filtro_infravermelho_proximo', [0, 0.8], [3, 1.5]);
# Out:
# Método outlier: Isolation Forest
# Quantidade de valores anômalos: 10000
# Quantidade de valores não anômalos: 90000
# Quantidade de valores lidos: 100000

# %%
pallete = ['#ff7f0e', '#1f77b4']
sns.pairplot(galaxy_data2, vars=entradas, hue='anomaly', palette=pallete)
